# %% [markdown]
# # The Tabular Data Model

# %%
# !mkdir data; pushd data; wget https://raw.githubusercontent.com/univai-ghf/ghfmedia/main/data/candidates.txt; wget https://raw.githubusercontent.com/univai-ghf/ghfmedia/main/data/contributors_with_candidate_id.txt; popd
# Out:
# --2024-04-05 13:24:19--  https://raw.githubusercontent.com/univai-ghf/ghfmedia/main/data/candidates.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 388 [text/plain]
# Saving to: ‘candidates.txt’
#
# candidates.txt      100%[===================>]     388  --.-KB/s    in 0s
#
# 2024-04-05 13:24:19 (33.6 MB/s) - ‘candidates.txt’ saved [388/388]
#
# --2024-04-05 13:24:19--  https://raw.githubusercontent.com/univai-ghf/ghfmedia/main/data/contributors_with_candidate_id.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14214 (14K) [text/plain]
# Saving to: ‘contributors_with_candidate_id.txt’
#
# contributors_with_c 100%[===================>]  13.88K  --.-KB/s    in 0s
#
# 2024-04-05 13:24:19 (86.3 MB/s) - ‘contributors_with_candidate_id.txt’ saved [14214/14214]

# %%
# !ls data
# Out:
# candidates.txt                     contributors_with_candidate_id.txt

# %%
import pandas as pd

# %%
from collections import OrderedDict
def make_frame(list_of_tuples, legend):
    framelist=[]
    for i, cname in enumerate(legend):
        framelist.append((cname,[e[i] for e in list_of_tuples]))
    return pd.DataFrame.from_dict(OrderedDict(framelist))

# %% [markdown]
# ## Pandas

# %% [markdown]
# Here is what the data looks like from the file `data/candidates.txt`
#
# ```
# id|first_name|last_name|middle_name|party
# 33|Joseph|Biden||D
# 36|Samuel|Brownback||R
# 34|Hillary|Clinton|R.|D
# 39|Christopher|Dodd|J.|D
# 26|John|Edwards||D
# 22|Rudolph|Giuliani||R
# 24|Mike|Gravel||D
# 16|Mike|Huckabee||R
# 30|Duncan|Hunter||R
# 31|Dennis|Kucinich||D
# 37|John|McCain||R
# 20|Barack|Obama||D
# 32|Ron|Paul||R
# 29|Bill|Richardson||D
# 35|Mitt|Romney||R
# 38|Tom|Tancredo||R
# 41|Fred|Thompson|D.|R
# ```

# %% [markdown]
# Use Pandas to read in the data

# %%
dfcand=pd.read_csv("data/candidates.txt", sep='|')
dfcand
# Out:
#     id   first_name   last_name middle_name party
# 0   33       Joseph       Biden         NaN     D
# 1   36       Samuel   Brownback         NaN     R
# 2   34      Hillary     Clinton          R.     D
# 3   39  Christopher        Dodd          J.     D
# 4   26         John     Edwards         NaN     D
# 5   22      Rudolph    Giuliani         NaN     R
# 6   24         Mike      Gravel         NaN     D
# 7   16         Mike    Huckabee         NaN     R
# 8   30       Duncan      Hunter         NaN     R
# 9   31       Dennis    Kucinich         NaN     D
# 10  37         John      McCain         NaN     R
# 11  20       Barack       Obama         NaN     D
# 12  32          Ron        Paul         NaN     R
# 13  29         Bill  Richardson         NaN     D
# 14  35         Mitt      Romney         NaN     R
# 15  38          Tom    Tancredo         NaN     R
# 16  41         Fred    Thompson          D.     R

# %% [markdown]
# Here is the other file, of contributions to candidates:
#
# ```
# id|last_name|first_name|middle_name|street_1|street_2|city|state|zip|amount|date|candidate_id
# |ABESHAUS|MERRILL|M.|1801 N. HEREFORD DRIVE||FLAGSTAFF|AZ|860011121|120.00|2008-01-16|37
# |ABRAHAM|GEORGE||P.O. BOX 1504||LAKE CHARLES|LA|706021504|800.00|2008-01-17|37
# |ABRAHAMSON|PETER|J.|1030 W. ROSCOE STREET||CHICAGO|IL|606572207|50.00|2008-01-25|37
# |ABRAHAM|SALEM|A.|P.O. BOX 7||CANADIAN|TX|790140007|1000.00|2008-01-17|37
# |ABRAHAM|SALEM|A.|P.O. BOX 7||CANADIAN|TX|790140007|1300.00|2008-01-30|37
# ```

# %%
dfcwci=pd.read_csv("data/contributors_with_candidate_id.txt", sep="|")
dfcwci.head()
# Out:
#    id last_name first_name middle_name                street_1 street_2  \
# 0 NaN      Agee     Steven         NaN  549 Laurel Branch Road      NaN
# 1 NaN    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 2 NaN    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 3 NaN    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 4 NaN      Akin    Charles         NaN  10187 Sugar Creek Road      NaN
#
#           city state    zip  amount        date  candidate_id
# 0        Floyd    VA  24091   500.0  2007-06-30            16
# 1   Pleasanton    CA  94566   250.0  2007-05-16            16
# 2   Pleasanton    CA  94566    50.0  2007-06-18            16
# 3   Pleasanton    CA  94566   100.0  2007-06-21            16
# 4  Bentonville    AR  72712   100.0  2007-06-16            16

# %% [markdown]
# You'll notice that the contributions dont have the first column, so we will need to be cleaning things up a bit...

# %%
del dfcwci['id']
dfcwci.head()
# Out:
#   last_name first_name middle_name                street_1 street_2  \
# 0      Agee     Steven         NaN  549 Laurel Branch Road      NaN
# 1    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 2    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 3    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 4      Akin    Charles         NaN  10187 Sugar Creek Road      NaN
#
#           city state    zip  amount        date  candidate_id
# 0        Floyd    VA  24091   500.0  2007-06-30            16
# 1   Pleasanton    CA  94566   250.0  2007-05-16            16
# 2   Pleasanton    CA  94566    50.0  2007-06-18            16
# 3   Pleasanton    CA  94566   100.0  2007-06-21            16
# 4  Bentonville    AR  72712   100.0  2007-06-16            16

# %%
dfcand.head(3)
# Out:
#    id first_name  last_name middle_name party
# 0  33     Joseph      Biden         NaN     D
# 1  36     Samuel  Brownback         NaN     R
# 2  34    Hillary    Clinton          R.     D

# %% [markdown]
# ## SQL and Relational Databases

# %% [markdown]
# Lets start with Relational Databases, so called because they contain "relations" (tables), which are SETS of "tuples" (rows) which map "attributes" (columns) to atomic values.
#
# The available attributes are constrained by a "header" tuple of attributes which set the type. We do this below here, using the SQL language to set things up.

# %% [markdown]
# ```sql
# DROP TABLE IF EXISTS "candidates";
# DROP TABLE IF EXISTS "contributors";
# CREATE TABLE "candidates" (
#     "id" INTEGER PRIMARY KEY  NOT NULL ,
#     "first_name" VARCHAR,
#     "last_name" VARCHAR,
#     "middle_name" VARCHAR,
#     "party" VARCHAR NOT NULL
# );
# CREATE TABLE "contributors" (
#     "id" INTEGER PRIMARY KEY  AUTOINCREMENT  NOT NULL,
#     "last_name" VARCHAR,
#     "first_name" VARCHAR,
#     "middle_name" VARCHAR,
#     "street_1" VARCHAR,
#     "street_2" VARCHAR,
#     "city" VARCHAR,
#     "state" VARCHAR,
#     "zip" VARCHAR, -- Notice that we are converting the zip from integer to string
#     "amount" INTEGER,
#     "date" DATETIME,
#     "candidate_id" INTEGER NOT NULL,
#     FOREIGN KEY(candidate_id) REFERENCES candidates(id)
# );
# ```

# %%
ourschema="""
DROP TABLE IF EXISTS "candidates";
DROP TABLE IF EXISTS "contributors";
CREATE TABLE "candidates" (
    "id" INTEGER PRIMARY KEY  NOT NULL ,
    "first_name" VARCHAR,
    "last_name" VARCHAR,
    "middle_name" VARCHAR,
    "party" VARCHAR NOT NULL
);
CREATE TABLE "contributors" (
    "id" INTEGER PRIMARY KEY  AUTOINCREMENT  NOT NULL,
    "last_name" VARCHAR,
    "first_name" VARCHAR,
    "middle_name" VARCHAR,
    "street_1" VARCHAR,
    "street_2" VARCHAR,
    "city" VARCHAR,
    "state" VARCHAR,
    "zip" VARCHAR, -- Notice that we are converting the zip from integer to string
    "amount" INTEGER,
    "date" DATETIME,
    "candidate_id" INTEGER NOT NULL,
    FOREIGN KEY(candidate_id) REFERENCES candidates(id)
);
"""

# %% [markdown]
# ### SQLITE

# %% [markdown]
# We use sqlite here (and recommend Postgres for production purposes). Sqlite is a on-file database, as opposed to other common databases such as Oracle and Postgres, which run as different processes on your system. Sqlite is great for on-disk large databases which wont fit into memory.
#
# Its also built into Python, but to use the [command line tool](https://www.sqlite.org/cli.html), I recommend you install it: https://www.sqlite.org/download.html. I also recommend you download and install the sqlite browser: http://sqlitebrowser.org .
#
# Python implements a standard database API over all databases. Its called [DBAPI2](http://cewing.github.io/training.codefellows/lectures/day21/intro_to_dbapi2.html). It works across many SQL databases.
#
# There is an even higher level API available, called [SQLAlchemy](http://www.sqlalchemy.org). While we wont use it here, I thoroughly recommend it. Many things in Pandas use it to interface with databases. Here we'll get away with things by using SQLITE.

# %% [markdown]
# We'll write some functions to connect to Sqlite.
#
# (1) Connect and get a DBAPI2 connection.

# %%
from sqlite3 import dbapi2 as sq3
from pathlib import Path
PATHSTART="."
def get_db(dbfile):
    sqlite_db = sq3.connect(Path(PATHSTART) / dbfile)
    return sqlite_db

# %% [markdown]
# (2) Set up the database with tables. Drop tables if they exist and create them.

# %%
def init_db(dbfile, schema):
    """Creates the database tables."""
    db = get_db(dbfile)
    db.cursor().executescript(schema)
    db.commit()
    return db

# %% [markdown]
# Initializing the database:

# %%
db=init_db("cancont.db", ourschema)

# %% [markdown]
# ### Populating with Pandas!!

# %%
dfcand.to_sql("candidates", db, if_exists="append", index=False)
# Out:
# 17

# %%
dfcwci.to_sql("contributors", db, if_exists="append", index=False)
# Out:
# 175

# %%
def make_query(sel):
    c=db.cursor().execute(sel)
    return c.fetchall()

# %%
make_query("SELECT * FROM candidates;")
# Out:
# [(16, 'Mike', 'Huckabee', None, 'R'),
#  (20, 'Barack', 'Obama', None, 'D'),
#  (22, 'Rudolph', 'Giuliani', None, 'R'),
#  (24, 'Mike', 'Gravel', None, 'D'),
#  (26, 'John', 'Edwards', None, 'D'),
#  (29, 'Bill', 'Richardson', None, 'D'),
#  (30, 'Duncan', 'Hunter', None, 'R'),
#  (31, 'Dennis', 'Kucinich', None, 'D'),
#  (32, 'Ron', 'Paul', None, 'R'),
#  (33, 'Joseph', 'Biden', None, 'D'),
#  (34, 'Hillary', 'Clinton', 'R.', 'D'),
#  (35, 'Mitt', 'Romney', None, 'R'),
#  (36, 'Samuel', 'Brownback', None, 'R'),
#  (37, 'John', 'McCain', None, 'R'),
#  (38, 'Tom', 'Tancredo', None, 'R'),
#  (39, 'Christopher', 'Dodd', 'J.', 'D'),
#  (41, 'Fred', 'Thompson', 'D.', 'R')]

# %%
make_query("PRAGMA table_info(candidates);")
# Out:
# [(0, 'id', 'INTEGER', 1, None, 1),
#  (1, 'first_name', 'VARCHAR', 0, None, 0),
#  (2, 'last_name', 'VARCHAR', 0, None, 0),
#  (3, 'middle_name', 'VARCHAR', 0, None, 0),
#  (4, 'party', 'VARCHAR', 1, None, 0)]

# %%
make_query("PRAGMA table_info(contributors);")
# Out:
# [(0, 'id', 'INTEGER', 1, None, 1),
#  (1, 'last_name', 'VARCHAR', 0, None, 0),
#  (2, 'first_name', 'VARCHAR', 0, None, 0),
#  (3, 'middle_name', 'VARCHAR', 0, None, 0),
#  (4, 'street_1', 'VARCHAR', 0, None, 0),
#  (5, 'street_2', 'VARCHAR', 0, None, 0),
#  (6, 'city', 'VARCHAR', 0, None, 0),
#  (7, 'state', 'VARCHAR', 0, None, 0),
#  (8, 'zip', 'VARCHAR', 0, None, 0),
#  (9, 'amount', 'INTEGER', 0, None, 0),
#  (10, 'date', 'DATETIME', 0, None, 0),
#  (11, 'candidate_id', 'INTEGER', 1, None, 0)]

# %%
candidate_cols = [e[1] for e in make_query("PRAGMA table_info(candidates);")]
candidate_cols
# Out:
# ['id', 'first_name', 'last_name', 'middle_name', 'party']

# %%
contributor_cols = [e[1] for e in make_query("PRAGMA table_info(contributors);")]
contributor_cols
# Out:
# ['id',
#  'last_name',
#  'first_name',
#  'middle_name',
#  'street_1',
#  'street_2',
#  'city',
#  'state',
#  'zip',
#  'amount',
#  'date',
#  'candidate_id']

# %%
out=make_query("SELECT * FROM candidates;")
make_frame(out, legend=candidate_cols)
# Out:
#     id   first_name   last_name middle_name party
# 0   16         Mike    Huckabee        None     R
# 1   20       Barack       Obama        None     D
# 2   22      Rudolph    Giuliani        None     R
# 3   24         Mike      Gravel        None     D
# 4   26         John     Edwards        None     D
# 5   29         Bill  Richardson        None     D
# 6   30       Duncan      Hunter        None     R
# 7   31       Dennis    Kucinich        None     D
# 8   32          Ron        Paul        None     R
# 9   33       Joseph       Biden        None     D
# 10  34      Hillary     Clinton          R.     D
# 11  35         Mitt      Romney        None     R
# 12  36       Samuel   Brownback        None     R
# 13  37         John      McCain        None     R
# 14  38          Tom    Tancredo        None     R
# 15  39  Christopher        Dodd          J.     D
# 16  41         Fred    Thompson          D.     R

# %% [markdown]
# ## THE GRAMMAR OF DATA

# %% [markdown]
# Let us now focus on core data manipulation commands. The reason to do this is that they are *universal across systems, and by identifying them, we can quickly ask how to do these* when we encounter a new system.

# %% [markdown]
# See https://gist.github.com/TomAugspurger/6e052140eaa5fdb6e8c0/ which has a comparison of r/dplyr and pandas. I stole and modified this table from there:
#
#
# ``dplyr`` has a small set of nicely defined verbs, which Hadley Wickham has used to identify core data manipulation commands. Here are listed the closest SQL and Pandas verbs, so we can see the universality of these manipulations.
#
# <table>
#   <tr>
#     <th><b>VERB</b></th>
#     <th><b>dplyr</b></th>
#     <th><b>pandas</b></th>
#     <th><b>SQL</b></th>
#   </tr>
#   <tr>
#     <td>QUERY/SELECTION</td>
#     <td>filter() (and slice())</td>
#     <td>query() (and loc[], iloc[])</td>
#     <td>SELECT WHERE</td>
#   </tr>
#   <tr>
#     <td>SORT</td>
#     <td>arrange()</td>
#     <td>sort_values()</td>
#     <td>ORDER BY</td>
#   </tr>
#   <tr>
#     <td>SELECT-COLUMNS/PROJECTION</td>
#     <td>select() (and rename())</td>
#     <td>[](__getitem__) (and rename())</td>
#     <td>SELECT COLUMN</td>
#   </tr>
#   <tr>
#     <td>SELECT-DISTINCT</td>
#     <td>distinct()</td>
#     <td>unique(),drop_duplicates()</td>
#     <td>SELECT DISTINCT COLUMN</td>
#   </tr>
#   <tr>
#     <td>ASSIGN</td>
#     <td>mutate() (and transmute())</td>
#     <td>assign</td>
#     <td>ALTER/UPDATE</td>
#   </tr>
#   <tr>
#     <td>AGGREGATE</td>
#     <td>summarise()</td>
#     <td>describe(), mean(), max()</td>
#     <td>None, AVG(),MAX()</td>
#   </tr>
#   <tr>
#     <td>SAMPLE</td>
#     <td>sample_n() and sample_frac()</td>
#     <td>sample()</td>
#     <td>implementation dep, use RAND()</td>
#   </tr>
#   <tr>
#     <td>GROUP-AGG</td>
#     <td>group_by/summarize</td>
#     <td>groupby/agg, count, mean</td>
#     <td>GROUP BY</td>
#   </tr>
#   <tr>
#     <td>DELETE</td>
#     <td>?</td>
#     <td>drop/masking</td>
#     <td>DELETE/WHERE</td>
#   </tr>
# </table>

# %% [markdown]
# ### QUERY
#
# We'll want to make queries on columns that are both numerical and categorical, combining these queries when appropriate...

# %%
dfcwci.query("20 <= amount <= 40")
# Out:
#     last_name first_name middle_name                    street_1 street_2  \
# 26    Buckler      Steve         NaN             24351 Armada Dr      NaN
# 49   Harrison       Ryan         NaN                 2247 3rd St      NaN
# 101    Aarons     Elaine         NaN  481 Buck Island Rd Apt 17A  APT 17A
# 140     ABEGG   PATRICIA          T.             1862 E. 5150 S.      NaN
# 143     ABEGG   PATRICIA          T.             1862 E. 5150 S.      NaN
# 144     ABEGG   PATRICIA          T.             1862 E. 5150 S.      NaN
# 158      ABBO    PAULINE     MORENCY            10720 JACOB LANE      NaN
# 160     ABAIR      PETER         NaN             40 EVANS STREET      NaN
#
#                city state        zip  amount        date  candidate_id
# 26       Dana Point    CA  926291306    25.0  2007-08-16            20
# 49         La Verne    CA  917504918    25.0  2007-07-26            20
# 101   West Yarmouth    MA   26733300    25.0  2008-02-26            34
# 140  SALT LAKE CITY    UT  841176911    25.0  2007-09-17            35
# 143  SALT LAKE CITY    UT  841176911    25.0  2007-08-06            35
# 144  SALT LAKE CITY    UT  841176911    25.0  2007-07-10            35
# 158      WHITE LAKE    MI  483862274    35.0  2008-01-07            37
# 160       WATERTOWN    MA   24722150    25.0  2008-01-09            37

# %%
out=make_query("SELECT * FROM contributors WHERE amount BETWEEN 20 AND 40;")
out
# Out:
# [(27,
#   'Buckler',
#   'Steve',
#   None,
#   '24351 Armada Dr',
#   None,
#   'Dana Point',
#   'CA',
#   '926291306',
#   25,
#   '2007-08-16',
#   20),
#  (50,
#   'Harrison',
#   'Ryan',
#   None,
#   '2247 3rd St',
#   None,
#   'La Verne',
#   'CA',
#   '917504918',
#   25,
#   '2007-07-26',
#   20),
#  (102,
#   'Aarons',
#   'Elaine',
#   None,
#   '481 Buck Island Rd Apt 17A',
#   'APT 17A',
#   'West Yarmouth',
#   'MA',
#   '26733300',
#   25,
#   '2008-02-26',
#   34),
#  (141,
#   'ABEGG',
#   'PATRICIA',
#   'T.',
#   '1862 E. 5150 S.',
#   None,
#   'SALT LAKE CITY',
#   'UT',
#   '841176911',
#   25,
#   '2007-09-17',
#   35),
#  (144,
#   'ABEGG',
#   'PATRICIA',
#   'T.',
#   '1862 E. 5150 S.',
#   None,
#   'SALT LAKE CITY',
#   'UT',
#   '841176911',
#   25,
#   '2007-08-06',
#   35),
#  (145,
#   'ABEGG',
#   'PATRICIA',
#   'T.',
#   '1862 E. 5150 S.',
#   None,
#   'SALT LAKE CITY',
#   'UT',
#   '841176911',
#   25,
#   '2007-07-10',
#   35),
#  (159,
#   'ABBO',
#   'PAULINE',
#   'MORENCY',
#   '10720 JACOB LANE',
#   None,
#   'WHITE LAKE',
#   'MI',
#   '483862274',
#   35,
#   '2008-01-07',
#   37),
#  (161,
#   'ABAIR',
#   'PETER',
#   None,
#   '40 EVANS STREET',
#   None,
#   'WATERTOWN',
#   'MA',
#   '24722150',
#   25,
#   '2008-01-09',
#   37)]

# %%
out=make_query("SELECT * FROM contributors WHERE amount BETWEEN 20 AND 40;")
make_frame(out, legend=contributor_cols)
# Out:
#     id last_name first_name middle_name                    street_1 street_2  \
# 0   27   Buckler      Steve        None             24351 Armada Dr     None
# 1   50  Harrison       Ryan        None                 2247 3rd St     None
# 2  102    Aarons     Elaine        None  481 Buck Island Rd Apt 17A  APT 17A
# 3  141     ABEGG   PATRICIA          T.             1862 E. 5150 S.     None
# 4  144     ABEGG   PATRICIA          T.             1862 E. 5150 S.     None
# 5  145     ABEGG   PATRICIA          T.             1862 E. 5150 S.     None
# 6  159      ABBO    PAULINE     MORENCY            10720 JACOB LANE     None
# 7  161     ABAIR      PETER        None             40 EVANS STREET     None
#
#              city state        zip  amount        date  candidate_id
# 0      Dana Point    CA  926291306      25  2007-08-16            20
# 1        La Verne    CA  917504918      25  2007-07-26            20
# 2   West Yarmouth    MA   26733300      25  2008-02-26            34
# 3  SALT LAKE CITY    UT  841176911      25  2007-09-17            35
# 4  SALT LAKE CITY    UT  841176911      25  2007-08-06            35
# 5  SALT LAKE CITY    UT  841176911      25  2007-07-10            35
# 6      WHITE LAKE    MI  483862274      35  2008-01-07            37
# 7       WATERTOWN    MA   24722150      25  2008-01-09            37

# %% [markdown]
# You can combine queries on different columns (here a numerical and a categorical):

# %%
dfcwci.query("state=='VA' & amount < 400")
# Out:
#      last_name first_name middle_name                     street_1 street_2  \
# 27    Buckheit      Bruce         NaN                8904 KAREN DR      NaN
# 77   Ranganath      Anoop         NaN           2507 Willard Drive      NaN
# 88   Perreault     Louise         NaN    503 Brockridge Hunt Drive      NaN
# 145    ABDELLA     THOMAS          M.  4231 MONUMENT WALL WAY #340      NaN
#
#                 city state        zip  amount        date  candidate_id
# 27           FAIRFAX    VA  220312731  100.00  2007-09-19            20
# 77   Charlottesville    VA      22903 -100.00  2008-04-21            32
# 88           Hampton    VA      23666  -34.08  2008-04-21            32
# 145          FAIRFAX    VA  220308440   50.00  2007-09-30            35

# %%
dfcwci.state=='VA'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 170    False
# 171    False
# 172    False
# 173    False
# 174    False
# Name: state, Length: 175, dtype: bool

# %%
dfcwci[(dfcwci.state=='VA') & (dfcwci.amount < 400)]
# Out:
#      last_name first_name middle_name                     street_1 street_2  \
# 27    Buckheit      Bruce         NaN                8904 KAREN DR      NaN
# 77   Ranganath      Anoop         NaN           2507 Willard Drive      NaN
# 88   Perreault     Louise         NaN    503 Brockridge Hunt Drive      NaN
# 145    ABDELLA     THOMAS          M.  4231 MONUMENT WALL WAY #340      NaN
#
#                 city state        zip  amount        date  candidate_id
# 27           FAIRFAX    VA  220312731  100.00  2007-09-19            20
# 77   Charlottesville    VA      22903 -100.00  2008-04-21            32
# 88           Hampton    VA      23666  -34.08  2008-04-21            32
# 145          FAIRFAX    VA  220308440   50.00  2007-09-30            35

# %%
out=make_query("SELECT * FROM contributors WHERE state='VA' AND amount < 400;")
make_frame(out, legend=contributor_cols)
# Out:
#     id  last_name first_name middle_name                     street_1  \
# 0   28   Buckheit      Bruce        None                8904 KAREN DR
# 1   78  Ranganath      Anoop        None           2507 Willard Drive
# 2   89  Perreault     Louise        None    503 Brockridge Hunt Drive
# 3  146    ABDELLA     THOMAS          M.  4231 MONUMENT WALL WAY #340
#
#   street_2             city state        zip  amount        date  candidate_id
# 0     None          FAIRFAX    VA  220312731  100.00  2007-09-19            20
# 1     None  Charlottesville    VA      22903 -100.00  2008-04-21            32
# 2     None          Hampton    VA      23666  -34.08  2008-04-21            32
# 3     None          FAIRFAX    VA  220308440   50.00  2007-09-30            35

# %% [markdown]
# Queries that look if things are in a list...useful for categorical variables or discrete valued numerical variables...

# %%
dfcwci.state.isin(['VA','WA'])
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 170    False
# 171    False
# 172    False
# 173    False
# 174    False
# Name: state, Length: 175, dtype: bool

# %%
dfcwci[dfcwci.state.isin(['VA','WA'])].head(10)
# Out:
#      last_name first_name middle_name                      street_1 street_2  \
# 0         Agee     Steven         NaN        549 Laurel Branch Road      NaN
# 27    Buckheit      Bruce         NaN                 8904 KAREN DR      NaN
# 62       BURKE    SUZANNE          M.                 3401 EVANSTON      NaN
# 77   Ranganath      Anoop         NaN            2507 Willard Drive      NaN
# 88   Perreault     Louise         NaN     503 Brockridge Hunt Drive      NaN
# 100   Aaronson    Rebecca         NaN  2000 Village Green Dr Apt 12      NaN
# 106   Aaronson    Rebecca         NaN  2000 Village Green Dr Apt 12      NaN
# 145    ABDELLA     THOMAS          M.   4231 MONUMENT WALL WAY #340      NaN
#
#                 city state        zip  amount        date  candidate_id
# 0              Floyd    VA      24091  500.00  2007-06-30            16
# 27           FAIRFAX    VA  220312731  100.00  2007-09-19            20
# 62           SEATTLE    WA  981038677 -700.00  2008-03-05            22
# 77   Charlottesville    VA      22903 -100.00  2008-04-21            32
# 88           Hampton    VA      23666  -34.08  2008-04-21            32
# 100       Mill Creek    WA  980125787  100.00  2008-02-08            34
# 106       Mill Creek    WA  980125787  100.00  2008-02-14            34
# 145          FAIRFAX    VA  220308440   50.00  2007-09-30            35

# %%
out=make_query("SELECT * FROM contributors WHERE state IN ('VA','WA');")
make_frame(out, legend=contributor_cols).head(10)
# Out:
#     id  last_name first_name middle_name                      street_1  \
# 0    1       Agee     Steven        None        549 Laurel Branch Road
# 1   28   Buckheit      Bruce        None                 8904 KAREN DR
# 2   63      BURKE    SUZANNE          M.                 3401 EVANSTON
# 3   78  Ranganath      Anoop        None            2507 Willard Drive
# 4   89  Perreault     Louise        None     503 Brockridge Hunt Drive
# 5  101   Aaronson    Rebecca        None  2000 Village Green Dr Apt 12
# 6  107   Aaronson    Rebecca        None  2000 Village Green Dr Apt 12
# 7  146    ABDELLA     THOMAS          M.   4231 MONUMENT WALL WAY #340
#
#   street_2             city state        zip  amount        date  candidate_id
# 0     None            Floyd    VA      24091  500.00  2007-06-30            16
# 1     None          FAIRFAX    VA  220312731  100.00  2007-09-19            20
# 2     None          SEATTLE    WA  981038677 -700.00  2008-03-05            22
# 3     None  Charlottesville    VA      22903 -100.00  2008-04-21            32
# 4     None          Hampton    VA      23666  -34.08  2008-04-21            32
# 5     None       Mill Creek    WA  980125787  100.00  2008-02-08            34
# 6     None       Mill Creek    WA  980125787  100.00  2008-02-14            34
# 7     None          FAIRFAX    VA  220308440   50.00  2007-09-30            35

# %% [markdown]
# Looking for data problems with nulls:

# %%
dfcwci[dfcwci.state.isnull()]
# Out:
#     last_name first_name middle_name       street_1 street_2        city  \
# 125    BOURNE     TRAVIS         NaN  LAGE KAART 77      NaN  BRASSCHATT
#
#     state   zip  amount        date  candidate_id
# 125   NaN  2930  -500.0  2008-11-20            35

# %%
out=make_query("SELECT * FROM contributors WHERE state IS NULL;")
out
# Out:
# [(126,
#   'BOURNE',
#   'TRAVIS',
#   None,
#   'LAGE KAART 77',
#   None,
#   'BRASSCHATT',
#   None,
#   '2930',
#   -500,
#   '2008-11-20',
#   35)]

# %%
out=make_query("SELECT * FROM contributors WHERE state IS NULL;")
make_frame(out, legend=contributor_cols)
# Out:
#     id last_name first_name middle_name       street_1 street_2        city  \
# 0  126    BOURNE     TRAVIS        None  LAGE KAART 77     None  BRASSCHATT
#
#   state   zip  amount        date  candidate_id
# 0  None  2930    -500  2008-11-20            35

# %% [markdown]
# Or the other way...

# %%
dfcwci[dfcwci.state.notnull()]
# Out:
#       last_name first_name middle_name                street_1 street_2  \
# 0          Agee     Steven         NaN  549 Laurel Branch Road      NaN
# 1        Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 2        Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 3        Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 4          Akin    Charles         NaN  10187 Sugar Creek Road      NaN
# ..          ...        ...         ...                     ...      ...
# 170    ABESHAUS    MERRILL          M.  1801 N. HEREFORD DRIVE      NaN
# 171     ABRAHAM     GEORGE         NaN           P.O. BOX 1504      NaN
# 172  ABRAHAMSON      PETER          J.   1030 W. ROSCOE STREET      NaN
# 173     ABRAHAM      SALEM          A.              P.O. BOX 7      NaN
# 174     ABRAHAM      SALEM          A.              P.O. BOX 7      NaN
#
#              city state        zip  amount        date  candidate_id
# 0           Floyd    VA      24091   500.0  2007-06-30            16
# 1      Pleasanton    CA      94566   250.0  2007-05-16            16
# 2      Pleasanton    CA      94566    50.0  2007-06-18            16
# 3      Pleasanton    CA      94566   100.0  2007-06-21            16
# 4     Bentonville    AR      72712   100.0  2007-06-16            16
# ..            ...   ...        ...     ...         ...           ...
# 170     FLAGSTAFF    AZ  860011121   120.0  2008-01-16            37
# 171  LAKE CHARLES    LA  706021504   800.0  2008-01-17            37
# 172       CHICAGO    IL  606572207    50.0  2008-01-25            37
# 173      CANADIAN    TX  790140007  1000.0  2008-01-17            37
# 174      CANADIAN    TX  790140007  1300.0  2008-01-30            37
#
# [174 rows x 11 columns]

# %%
out=make_query("SELECT * FROM contributors WHERE state IS NOT NULL;")
make_frame(out, legend=contributor_cols)
# Out:
#       id   last_name first_name middle_name                street_1 street_2  \
# 0      1        Agee     Steven        None  549 Laurel Branch Road     None
# 1      2      Ahrens        Don        None    4034 Rennellwood Way     None
# 2      3      Ahrens        Don        None    4034 Rennellwood Way     None
# 3      4      Ahrens        Don        None    4034 Rennellwood Way     None
# 4      5        Akin    Charles        None  10187 Sugar Creek Road     None
# ..   ...         ...        ...         ...                     ...      ...
# 169  171    ABESHAUS    MERRILL          M.  1801 N. HEREFORD DRIVE     None
# 170  172     ABRAHAM     GEORGE        None           P.O. BOX 1504     None
# 171  173  ABRAHAMSON      PETER          J.   1030 W. ROSCOE STREET     None
# 172  174     ABRAHAM      SALEM          A.              P.O. BOX 7     None
# 173  175     ABRAHAM      SALEM          A.              P.O. BOX 7     None
#
#              city state        zip  amount        date  candidate_id
# 0           Floyd    VA      24091   500.0  2007-06-30            16
# 1      Pleasanton    CA      94566   250.0  2007-05-16            16
# 2      Pleasanton    CA      94566    50.0  2007-06-18            16
# 3      Pleasanton    CA      94566   100.0  2007-06-21            16
# 4     Bentonville    AR      72712   100.0  2007-06-16            16
# ..            ...   ...        ...     ...         ...           ...
# 169     FLAGSTAFF    AZ  860011121   120.0  2008-01-16            37
# 170  LAKE CHARLES    LA  706021504   800.0  2008-01-17            37
# 171       CHICAGO    IL  606572207    50.0  2008-01-25            37
# 172      CANADIAN    TX  790140007  1000.0  2008-01-17            37
# 173      CANADIAN    TX  790140007  1300.0  2008-01-30            37
#
# [174 rows x 12 columns]

# %% [markdown]
# ### SORT AND LIMIT
#
# After possibly making a query, we want to sort our results...

# %%
dfcwci.sort_values("amount").head(10)
# Out:
#    last_name   first_name middle_name                      street_1 street_2  \
# 90     Kazor  Christopher           M           707 Spindletree ave      NaN
# 72     BRUNO         JOHN         NaN  10136 WINDERMERE CHASE BLVD.      NaN
# 64     BURKE       DONALD          J.                     12 LOMPOC      NaN
# 73     BRUNO        IRENE         NaN  10136 WINDERMERE CHASE BLVD.      NaN
# 74     BROWN      TIMOTHY          J.           26826 MARLOWE COURT      NaN
# 58    BURTON        GLENN          M.         4404 CHARLESTON COURT      NaN
# 57    BURTON       STEVEN          G.         9938 DEER CREEK DRIVE      NaN
# 84   Uihlein      Richard         NaN            1396 N Waukegan Rd      NaN
# 56    BURTON        SUSAN         NaN         9338 DEER CREEK DRIVE      NaN
# 55      BUSH         ERIC         NaN                P.O. BOX 61046      NaN
#
#                   city state        zip  amount        date  candidate_id
# 90          Naperville    IL      60565 -2592.0  2008-04-21            32
# 72               GOTHA    FL  347344707 -2300.0  2008-03-06            22
# 64  RANCHO SANTA MARGA    CA  926881817 -2300.0  2008-03-11            22
# 73               GOTHA    FL  347344707 -2300.0  2008-03-06            22
# 74     STEVENSON RANCH    CA  913811020 -2300.0  2008-03-06            22
# 58               TAMPA    FL  336092620 -2300.0  2008-03-05            22
# 57               TAMPA    FL      33647 -2300.0  2008-03-05            22
# 84         Lake Forest    IL  600451147 -2300.0  2008-04-21            32
# 56               TAMPA    FL  336472286 -2300.0  2008-03-05            22
# 55              DENVER    CO  802061046 -2300.0  2008-03-06            22

# %%
dfcwci.sort_values("amount", ascending=False).head(10)
# Out:
#       last_name first_name middle_name                 street_1 street_2  \
# 30       Buckel      Linda         NaN            PO Box 683130      NaN
# 159       ABATE      MARIA       ELENA  1291 NIGHTINGALE AVENUE      NaN
# 15      Anthony       John         NaN    211 Long Island Drive      NaN
# 33         Buck     Blaine           M             45 Eaton Ave      NaN
# 28       Buckel      Linda         NaN            PO Box 683130      NaN
# 21        Baker      David         NaN   2550 Adamsbrooke Drive      NaN
# 13        Altes       R.D.         NaN          8600 Moody Road      NaN
# 135  ABRAMOWITZ       NIRA         NaN          411 HARBOR ROAD      NaN
# 5          Akin       Mike         NaN         181 Baywood Lane      NaN
# 174     ABRAHAM      SALEM          A.               P.O. BOX 7      NaN
#
#               city state        zip  amount        date  candidate_id
# 30       Park City    UT  840683130  4600.0  2007-08-14            20
# 159  MIAMI SPRINGS    FL  331663832  2600.0  2008-01-25            37
# 15     Hot Springs    AR      71913  2300.0  2007-06-12            16
# 33          Camden    ME   48431752  2300.0  2007-09-30            20
# 28       Park City    UT  840683130  2300.0  2007-08-14            20
# 21          Conway    AR      72034  2300.0  2007-04-11            16
# 13      Fort Smith    AR      72903  2300.0  2007-06-21            16
# 135      SOUTHPORT    CT   68901376  2300.0  2007-09-14            35
# 5       Monticello    AR      71655  1500.0  2007-05-18            16
# 174       CANADIAN    TX  790140007  1300.0  2008-01-30            37

# %%
out=make_query("SELECT * FROM contributors ORDER BY amount;")
make_frame(out, legend=contributor_cols).head(10)
# Out:
#    id last_name   first_name middle_name                   street_1 street_2  \
# 0  91     Kazor  Christopher           M        707 Spindletree ave     None
# 1  30    Buckel        Linda        None              PO Box 683130     None
# 2  52  BYINGTON     MARGARET          E.  2633 MIDDLEBORO LANE N.E.     None
# 3  53     BYERS          BOB          A.       13170 TELFAIR AVENUE     None
# 4  55      BUSH      KRYSTIE        None             P.O. BOX 61046     None
# 5  56      BUSH         ERIC        None             P.O. BOX 61046     None
# 6  57    BURTON        SUSAN        None      9338 DEER CREEK DRIVE     None
# 7  58    BURTON       STEVEN          G.      9938 DEER CREEK DRIVE     None
# 8  59    BURTON        GLENN          M.      4404 CHARLESTON COURT     None
# 9  65     BURKE       DONALD          J.                  12 LOMPOC     None
#
#                  city state        zip  amount        date  candidate_id
# 0          Naperville    IL      60565 -2592.0  2008-04-21            32
# 1           Park City    UT  840683130 -2300.0  2007-08-14            20
# 2        GRAND RAPIDS    MI  495061254 -2300.0  2008-03-03            22
# 3              SYLMAR    CA  913423573 -2300.0  2008-03-07            22
# 4              DENVER    CO  802061046 -2300.0  2008-03-06            22
# 5              DENVER    CO  802061046 -2300.0  2008-03-06            22
# 6               TAMPA    FL  336472286 -2300.0  2008-03-05            22
# 7               TAMPA    FL      33647 -2300.0  2008-03-05            22
# 8               TAMPA    FL  336092620 -2300.0  2008-03-05            22
# 9  RANCHO SANTA MARGA    CA  926881817 -2300.0  2008-03-11            22

# %%
out=make_query("SELECT * FROM contributors ORDER BY amount DESC;")
make_frame(out, legend=contributor_cols).head(10)
# Out:
#     id   last_name first_name middle_name                 street_1 street_2  \
# 0   31      Buckel      Linda        None            PO Box 683130     None
# 1  160       ABATE      MARIA       ELENA  1291 NIGHTINGALE AVENUE     None
# 2   14       Altes       R.D.        None          8600 Moody Road     None
# 3   16     Anthony       John        None    211 Long Island Drive     None
# 4   22       Baker      David        None   2550 Adamsbrooke Drive     None
# 5   29      Buckel      Linda        None            PO Box 683130     None
# 6   34        Buck     Blaine           M             45 Eaton Ave     None
# 7  136  ABRAMOWITZ       NIRA        None          411 HARBOR ROAD     None
# 8    6        Akin       Mike        None         181 Baywood Lane     None
# 9   10       Allen    John D.        None   1052 Cannon Mill Drive     None
#
#             city state        zip  amount        date  candidate_id
# 0      Park City    UT  840683130  4600.0  2007-08-14            20
# 1  MIAMI SPRINGS    FL  331663832  2600.0  2008-01-25            37
# 2     Fort Smith    AR      72903  2300.0  2007-06-21            16
# 3    Hot Springs    AR      71913  2300.0  2007-06-12            16
# 4         Conway    AR      72034  2300.0  2007-04-11            16
# 5      Park City    UT  840683130  2300.0  2007-08-14            20
# 6         Camden    ME   48431752  2300.0  2007-09-30            20
# 7      SOUTHPORT    CT   68901376  2300.0  2007-09-14            35
# 8     Monticello    AR      71655  1500.0  2007-05-18            16
# 9  North Augusta    SC      29860  1300.0  2007-06-29            16

# %%
dfcwci[0:10] #.head(10)
# Out:
#   last_name first_name middle_name                      street_1 street_2  \
# 0      Agee     Steven         NaN        549 Laurel Branch Road      NaN
# 1    Ahrens        Don         NaN          4034 Rennellwood Way      NaN
# 2    Ahrens        Don         NaN          4034 Rennellwood Way      NaN
# 3    Ahrens        Don         NaN          4034 Rennellwood Way      NaN
# 4      Akin    Charles         NaN        10187 Sugar Creek Road      NaN
# 5      Akin       Mike         NaN              181 Baywood Lane      NaN
# 6      Akin    Rebecca         NaN              181 Baywood Lane      NaN
# 7  Aldridge    Brittni         NaN  808 Capitol Square Place, SW      NaN
# 8     Allen    John D.         NaN        1052 Cannon Mill Drive      NaN
# 9     Allen    John D.         NaN        1052 Cannon Mill Drive      NaN
#
#             city state    zip  amount        date  candidate_id
# 0          Floyd    VA  24091   500.0  2007-06-30            16
# 1     Pleasanton    CA  94566   250.0  2007-05-16            16
# 2     Pleasanton    CA  94566    50.0  2007-06-18            16
# 3     Pleasanton    CA  94566   100.0  2007-06-21            16
# 4    Bentonville    AR  72712   100.0  2007-06-16            16
# 5     Monticello    AR  71655  1500.0  2007-05-18            16
# 6     Monticello    AR  71655   500.0  2007-05-18            16
# 7     Washington    DC  20024   250.0  2007-06-06            16
# 8  North Augusta    SC  29860  1000.0  2007-06-11            16
# 9  North Augusta    SC  29860  1300.0  2007-06-29            16

# %%
out=make_query("SELECT * FROM contributors ORDER BY amount DESC LIMIT 10;")
make_frame(out, legend=contributor_cols)
# Out:
#     id   last_name first_name middle_name                 street_1 street_2  \
# 0   31      Buckel      Linda        None            PO Box 683130     None
# 1  160       ABATE      MARIA       ELENA  1291 NIGHTINGALE AVENUE     None
# 2   14       Altes       R.D.        None          8600 Moody Road     None
# 3   16     Anthony       John        None    211 Long Island Drive     None
# 4   22       Baker      David        None   2550 Adamsbrooke Drive     None
# 5   29      Buckel      Linda        None            PO Box 683130     None
# 6   34        Buck     Blaine           M             45 Eaton Ave     None
# 7  136  ABRAMOWITZ       NIRA        None          411 HARBOR ROAD     None
# 8    6        Akin       Mike        None         181 Baywood Lane     None
# 9   10       Allen    John D.        None   1052 Cannon Mill Drive     None
#
#             city state        zip  amount        date  candidate_id
# 0      Park City    UT  840683130    4600  2007-08-14            20
# 1  MIAMI SPRINGS    FL  331663832    2600  2008-01-25            37
# 2     Fort Smith    AR      72903    2300  2007-06-21            16
# 3    Hot Springs    AR      71913    2300  2007-06-12            16
# 4         Conway    AR      72034    2300  2007-04-11            16
# 5      Park City    UT  840683130    2300  2007-08-14            20
# 6         Camden    ME   48431752    2300  2007-09-30            20
# 7      SOUTHPORT    CT   68901376    2300  2007-09-14            35
# 8     Monticello    AR      71655    1500  2007-05-18            16
# 9  North Augusta    SC      29860    1300  2007-06-29            16

# %% [markdown]
# ### SELECT-COLUMNS
#
# Sometimes we only want to get a few columns, not the entire table

# %%
dfcwci[['first_name', 'amount']].head(10)
# Out:
#   first_name  amount
# 0     Steven   500.0
# 1        Don   250.0
# 2        Don    50.0
# 3        Don   100.0
# 4    Charles   100.0
# 5       Mike  1500.0
# 6    Rebecca   500.0
# 7    Brittni   250.0
# 8    John D.  1000.0
# 9    John D.  1300.0

# %%
out=make_query("SELECT first_name, amount FROM contributors;")
make_frame(out,['first_name', 'amount']).head(10)
# Out:
#   first_name  amount
# 0     Steven   500.0
# 1        Don   250.0
# 2        Don    50.0
# 3        Don   100.0
# 4    Charles   100.0
# 5       Mike  1500.0
# 6    Rebecca   500.0
# 7    Brittni   250.0
# 8    John D.  1000.0
# 9    John D.  1300.0

# %% [markdown]
# ### AGGREGATE

# %%
dfcwci.describe()
# Out:
#                 zip       amount  candidate_id
# count  1.750000e+02   175.000000    175.000000
# mean   3.780014e+08     3.418114     28.000000
# std    3.628278e+08  1028.418999      7.823484
# min    2.474000e+03 -2592.000000     16.000000
# 25%    9.336700e+04  -175.000000     20.000000
# 50%    3.233313e+08   100.000000     32.000000
# 75%    7.816946e+08   300.000000     35.000000
# max    9.951532e+08  4600.000000     37.000000

# %%
dfcwci.amount.max()
# Out:
# 4600.0

# %% [markdown]
# SQL is actually simpler

# %%
out=make_query("SELECT MAX(amount) FROM contributors;")
out
# Out:
# [(4600,)]

# %% [markdown]
# Aso `MIN`, `SUM`, `AVG`.

# %%
out=make_query("SELECT AVG(amount) FROM contributors;")
out
# Out:
# [(3.4181142857142857,)]

# %%
out=make_query("SELECT *, MAX(amount) AS maxamt FROM contributors;")
print(out)
make_frame(out, legend=contributor_cols+['maxamt'])
# Out:
# [(31, 'Buckel', 'Linda', None, 'PO Box 683130', None, 'Park City', 'UT', '840683130', 4600, '2007-08-14', 20, 4600)]
#    id last_name first_name middle_name       street_1 street_2       city  \
# 0  31    Buckel      Linda        None  PO Box 683130     None  Park City
#
#   state        zip  amount        date  candidate_id  maxamt
# 0    UT  840683130    4600  2007-08-14            20    4600

# %% [markdown]
# As a sneak preview of a "subselection" feature we'll talk about when we talk about relationships in databases next week, we can use subselects to implement an algebraic style query...

# %%
out=make_query("SELECT * FROM contributors WHERE amount > (select (MAX(amount) - 2300) FROM contributors);")
make_frame(out, legend=contributor_cols)
# Out:
#     id last_name first_name middle_name                 street_1 street_2  \
# 0   31    Buckel      Linda        None            PO Box 683130     None
# 1  160     ABATE      MARIA       ELENA  1291 NIGHTINGALE AVENUE     None
#
#             city state        zip  amount        date  candidate_id
# 0      Park City    UT  840683130    4600  2007-08-14            20
# 1  MIAMI SPRINGS    FL  331663832    2600  2008-01-25            37

# %% [markdown]
# ### GROUP-AGG
#
# Being able to group data by the value of any column is critical functionality. This is how you understand your sampling, and the distributions of various quantities in your data.

# %%
dfcwci.groupby("state").sum()
# Out:
#                                                last_name  \
# state
# AK                                    AARONSAARONSAARONS
# AR     AkinAkinAkinAllisonAllisonAllisonAltesAnthonyA...
# AZ                                              ABESHAUS
# CA     AhrensAhrensAhrensBancroftBucklerBucklerBuchma...
# CO                             BUSHBUSHEskenberrySECRIST
# CT                                            ABRAMOWITZ
# DC           AldridgeBuchananBURKHARDTBURKHARDTBURKHARDT
# FL     BuckBuckBuchananBuchananBuchananBuchananBuchan...
# IA                                                Andres
# ID                                               Gaarder
# IL           BuckBUKOWSKIUihleinFroehlingKazorABRAHAMSON
# KS                                                 Kuehn
# KY                                               BUISSON
# LA                                          ABELEABRAHAM
# MA                   NystromAaronsAaronsAaronsABBOTABAIR
# MD                                        BuchanekABRAMS
# ME                                   BuckAaronAaronAaron
# MI                          BYINGTONAaronAaronABBOTTABBO
# MN                               WaddellAanonsenAanonsen
# MO                                                  Buck
# NC                                                Barbee
# NH                                               Plummer
# NJ                                         RozenfeldChoe
# NV                                ACCORDABTSABBOTTABBOTT
# NY          BURKEBULLBULLSchuffDuryeaReidReichABRAMOWITZ
# OH                           ArbogastArbogastArdleLehner
# OK                                       AaronAaronAaron
# PA                       BUCKLEYBUCKLEYRaughtFerraraABEL
# RI                                          ABBOTTABBOTT
# SC                                        AllenAllenABEL
# TN                                                 Hobbs
# TX     BURGERTMuseJohnsonABREUABREUABREUABERCROMBIEAB...
# UT     BuckelBuckelBuckelABEGGABEGGABEGGABEGGABEGGABE...
# VA                 AgeeBuckheitRanganathPerreaultABDELLA
# WA                                 BURKEAaronsonAaronson
#
#                                               first_name  \
# state
# AK                                 CHARLESCHARLESCHARLES
# AR     CharlesMikeRebeccaJohn W.RebeccaRebeccaR.D.Joh...
# AZ                                               MERRILL
# CA     DonDonDonDavidSteveSteveMark MIdaRyanBOBAUDREY...
# CO                                KRYSTIEERICRobertBRIAN
# CT                                                  NIRA
# DC                          BrittniJohnCRAIGCRAIGBARBARA
# FL     BarbaraBarbaraJohnJohnJohnJohnJohnJohnJohnJohn...
# IA                                                  Dale
# ID                                                 Bruce
# IL                  JayDANIELRichardAlanChristopherPETER
# KS                                                 David
# KY                                              MARGARET
# LA                                          RODNEYGEORGE
# MA                   MichaelElaineElaineElaineDAVIDPETER
# MD                                      ElizabethMICHAEL
# ME                              BlaineCaroleCaroleCarole
# MI                           MARGARETJimJimROBERTPAULINE
# MN                                           JamesLinLin
# MO                                                Thomas
# NC                                                  John
# NH                                                Joseph
# NJ                                        TimurHyeokchan
# NV                                   DEANHENRYSYBILSYBIL
# NY         GAILBARTLEBARTLEBryanMarciaElizabethThomasKEN
# OH                             RobertRobertWilliamThomas
# OK                               SharronPatriciaPatricia
# PA                        WALTERMARJORIEPhilipJudithJOHN
# RI                                          GERALDGERALD
# SC                                 John D.John D.MARLING
# TN                                                 James
# TX      RONALDNinaCathleenKEVINKEVINKEVINDENISSALEMSALEM
# UT     LindaLindaLindaPATRICIAPATRICIAPATRICIAPATRICI...
# VA                          StevenBruceAnoopLouiseTHOMAS
# WA                                 SUZANNERebeccaRebecca
#
#                          middle_name  \
# state
# AK                                 0
# AR                                 0
# IL     -5586.80  2007-09-122008-03-102008-04-212008-04-212008-0...
# KS      -330.00                                         2008-04-21
# KY      -200.00                                         2008-03-11
# LA      1300.00                               2008-01-152008-01-17
# MA       -83.00  2008-04-212008-02-262008-02-252008-02-082008-0...
# MD       300.00                               2007-09-302007-09-29
# ME      2520.00           2007-09-302008-02-292008-02-072008-02-03
# MI     -1265.00  2008-03-032008-02-072008-02-292008-01-212008-0...
# MN       322.00                     2008-04-212008-02-212008-02-08
# MO       100.00                                         2007-09-25
# NC       500.00                                         2007-05-23
# NH       -24.60                                         2008-04-21
# NJ      -817.45                               2008-04-212008-04-21
# NV       725.00           2007-07-132007-07-132008-01-082008-01-08
# NY     -6474.50  2008-03-052008-03-102008-03-102008-08-222008-0...
# OH       450.00           2007-04-082007-06-222007-06-282008-04-21
# OK       800.00                     2008-02-092008-02-262008-02-12
# PA     -2146.00  2008-03-052008-03-052008-04-212008-04-212008-0...
# RI       200.00                               2007-09-152007-08-15
# SC      2400.00                     2007-06-112007-06-292008-01-22
# TN       -25.00                                         2008-08-19
# TX      1985.24  2008-03-052008-04-212008-04-212007-09-302007-0...
# UT      5050.00  2007-08-142007-08-142007-08-142007-09-252007-0...
# VA       515.92  2007-06-302007-09-192008-04-212008-04-212007-0...
# WA      -500.00                     2008-03-052008-02-082008-02-14
#
#        candidate_id
# state
# AK              111
# AR              192
# AZ               37
# CA              600
# CO              111
# CT               35
# DC              102
# FL              803
# IA               16
# ID               32
# IL              175
# KS               32
# KY               22
# LA               74
# MA              208
# MD               55
# ME              122
# MI              164
# MN              100
# MO               20
# NC               16
# NH               32
# NJ               64
# NV              144
# NY              233
# OH               80
# OK              102
# PA              145
# RI               70
# SC               69
# TN               32
# TX              302
# UT              340
# VA              135
# WA               90

# %%
dfcwci.groupby("state")['amount'].mean()
# Out:
# state
# AK     403.333333
# AR    1183.333333
# AZ     120.000000
# CA    -217.988261
# CO   -1455.750000
# CT    2300.000000
# DC    -309.982000
# FL    -135.000000
# IA     250.000000
# ID    -261.000000
# IL    -931.133333
# KS    -330.000000
# KY    -200.000000
# LA     650.000000
# MA     -13.833333
# MD     150.000000
# ME     630.000000
# MI    -253.000000
# MN     107.333333
# MO     100.000000
# NC     500.000000
# NH     -24.600000
# NJ    -408.725000
# NV     181.250000
# NY    -809.312500
# OH     112.500000
# OK     266.666667
# PA    -429.200000
# RI     100.000000
# SC     800.000000
# TN     -25.000000
# TX     220.582222
# UT     459.090909
# VA     103.184000
# WA    -166.666667
# Name: amount, dtype: float64

# %%
out=make_query("SELECT state,AVG(amount) FROM contributors GROUP BY state;")
print(out)
make_frame(out, legend=['state','mean'])
# Out:
# [(None, -500.0), ('AK', 403.3333333333333), ('AR', 1183.3333333333333), ('AZ', 120.0), ('CA', -217.9882608695652), ('CO', -1455.75), ('CT', 2300.0), ('DC', -309.982), ('FL', -135.0), ('IA', 250.0), ('ID', -261.0), ('IL', -931.1333333333333), ('KS', -330.0), ('KY', -200.0), ('LA', 650.0), ('MA', -13.833333333333334), ('MD', 150.0), ('ME', 630.0), ('MI', -253.0), ('MN', 107.33333333333333), ('MO', 100.0), ('NC', 500.0), ('NH', -24.6), ('NJ', -408.725), ('NV', 181.25), ('NY', -809.3125), ('OH', 112.5), ('OK', 266.6666666666667), ('PA', -429.2), ('RI', 100.0), ('SC', 800.0), ('TN', -25.0), ('TX', 220.5822222222222), ('UT', 459.09090909090907), ('VA', 103.184), ('WA', -166.66666666666666)]
#    state         mean
# 0   None  -500.000000
# 1     AK   403.333333
# 2     AR  1183.333333
# 3     AZ   120.000000
# 4     CA  -217.988261
# 5     CO -1455.750000
# 6     CT  2300.000000
# 7     DC  -309.982000
# 8     FL  -135.000000
# 9     IA   250.000000
# 10    ID  -261.000000
# 11    IL  -931.133333
# 12    KS  -330.000000
# 13    KY  -200.000000
# 14    LA   650.000000
# 15    MA   -13.833333
# 16    MD   150.000000
# 17    ME   630.000000
# 18    MI  -253.000000
# 19    MN   107.333333
# 20    MO   100.000000
# 21    NC   500.000000
# 22    NH   -24.600000
# 23    NJ  -408.725000
# 24    NV   181.250000
# 25    NY  -809.312500
# 26    OH   112.500000
# 27    OK   266.666667
# 28    PA  -429.200000
# 29    RI   100.000000
# 30    SC   800.000000
# 31    TN   -25.000000
# 32    TX   220.582222
# 33    UT   459.090909
# 34    VA   103.184000
# 35    WA  -166.666667

# %% [markdown]
# ### Create new columns with ASSIGN
#
# In Pandas it is simple to create a new column (`pd.Series`) in the dataframe:

# %%
dfcwci['name']=dfcwci['last_name']+", "+dfcwci['first_name']
dfcwci.head(10)
# Out:
#   last_name first_name middle_name                      street_1 street_2  \
# 0      Agee     Steven         NaN        549 Laurel Branch Road      NaN
# 1    Ahrens        Don         NaN          4034 Rennellwood Way      NaN
# 2    Ahrens        Don         NaN          4034 Rennellwood Way      NaN
# 3    Ahrens        Don         NaN          4034 Rennellwood Way      NaN
# 4      Akin    Charles         NaN        10187 Sugar Creek Road      NaN
# 5      Akin       Mike         NaN              181 Baywood Lane      NaN
# 6      Akin    Rebecca         NaN              181 Baywood Lane      NaN
# 7  Aldridge    Brittni         NaN  808 Capitol Square Place, SW      NaN
# 8     Allen    John D.         NaN        1052 Cannon Mill Drive      NaN
# 9     Allen    John D.         NaN        1052 Cannon Mill Drive      NaN
#
#             city state    zip  amount        date  candidate_id  \
# 0          Floyd    VA  24091   500.0  2007-06-30            16
# 1     Pleasanton    CA  94566   250.0  2007-05-16            16
# 2     Pleasanton    CA  94566    50.0  2007-06-18            16
# 3     Pleasanton    CA  94566   100.0  2007-06-21            16
# 4    Bentonville    AR  72712   100.0  2007-06-16            16
# 5     Monticello    AR  71655  1500.0  2007-05-18            16
# 6     Monticello    AR  71655   500.0  2007-05-18            16
# 7     Washington    DC  20024   250.0  2007-06-06            16
# 8  North Augusta    SC  29860  1000.0  2007-06-11            16
# 9  North Augusta    SC  29860  1300.0  2007-06-29            16
#
#                 name
# 0       Agee, Steven
# 1        Ahrens, Don
# 2        Ahrens, Don
# 3        Ahrens, Don
# 4      Akin, Charles
# 5         Akin, Mike
# 6      Akin, Rebecca
# 7  Aldridge, Brittni
# 8     Allen, John D.
# 9     Allen, John D.

# %% [markdown]
# One can also use `assign`, which creates a new dataframe...

# %%
newdf = dfcwci.assign(ucname=dfcwci.last_name+":"+dfcwci.first_name).head(10)
newdf.head()
# Out:
#   last_name first_name middle_name                street_1 street_2  \
# 0      Agee     Steven         NaN  549 Laurel Branch Road      NaN
# 1    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 2    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 3    Ahrens        Don         NaN    4034 Rennellwood Way      NaN
# 4      Akin    Charles         NaN  10187 Sugar Creek Road      NaN
#
#           city state    zip  amount        date  candidate_id           name  \
# 0        Floyd    VA  24091   500.0  2007-06-30            16   Agee, Steven
# 1   Pleasanton    CA  94566   250.0  2007-05-16            16    Ahrens, Don
# 2   Pleasanton    CA  94566    50.0  2007-06-18            16    Ahrens, Don
# 3   Pleasanton    CA  94566   100.0  2007-06-21            16    Ahrens, Don
# 4  Bentonville    AR  72712   100.0  2007-06-16            16  Akin, Charles
#
#          ucname
# 0   Agee:Steven
# 1    Ahrens:Don
# 2    Ahrens:Don
# 3    Ahrens:Don
# 4  Akin:Charles

# %% [markdown]
# Will the above command actually change `dfcwci`? `assign` creates a whole new dataframe. The dictionary style assigns in memory.
#
# **What if we wanted to change an existing assignment?**
#
# In other words, we are not creating a new column, but rather changing the values associated with a column, based on some criterion

# %%
dfcwci[dfcwci.state=='VA']
# Out:
#      last_name first_name middle_name                     street_1 street_2  \
# 0         Agee     Steven         NaN       549 Laurel Branch Road      NaN
# 27    Buckheit      Bruce         NaN                8904 KAREN DR      NaN
# 77   Ranganath      Anoop         NaN           2507 Willard Drive      NaN
# 88   Perreault     Louise         NaN    503 Brockridge Hunt Drive      NaN
# 145    ABDELLA     THOMAS          M.  4231 MONUMENT WALL WAY #340      NaN
#
#                 city state        zip  amount        date  candidate_id  \
# 0              Floyd    VA      24091  500.00  2007-06-30            16
# 27           FAIRFAX    VA  220312731  100.00  2007-09-19            20
# 77   Charlottesville    VA      22903 -100.00  2008-04-21            32
# 88           Hampton    VA      23666  -34.08  2008-04-21            32
# 145          FAIRFAX    VA  220308440   50.00  2007-09-30            35
#
#                   name
# 0         Agee, Steven
# 27     Buckheit, Bruce
# 77    Ranganath, Anoop
# 88   Perreault, Louise
# 145    ABDELLA, THOMAS

# %% [markdown]
# Lets get the `name` column we just created...

# %%
dfcwci.loc[dfcwci.state=='VA', 'name']
# Out:
# 0           Agee, Steven
# 27       Buckheit, Bruce
# 77      Ranganath, Anoop
# 88     Perreault, Louise
# 145      ABDELLA, THOMAS
# Name: name, dtype: object

# %% [markdown]
# Now we set the names from Virginia to be "junk":

# %%
dfcwci.loc[dfcwci.state=='VA', 'name']="junk"

# %%
dfcwci.query("state=='VA'")['name']
# Out:
# 0      junk
# 27     junk
# 77     junk
# 88     junk
# 145    junk
# Name: name, dtype: object

# %% [markdown]
# ---
#
# Let us see the entire process in SQL

# %%
alt="ALTER TABLE contributors ADD COLUMN name;"
db.cursor().execute(alt)
db.commit()

# %%
make_query("PRAGMA table_info(contributors);")
# Out:
# [(0, 'id', 'INTEGER', 1, None, 1),
#  (1, 'last_name', 'VARCHAR', 0, None, 0),
#  (2, 'first_name', 'VARCHAR', 0, None, 0),
#  (3, 'middle_name', 'VARCHAR', 0, None, 0),
#  (4, 'street_1', 'VARCHAR', 0, None, 0),
#  (5, 'street_2', 'VARCHAR', 0, None, 0),
#  (6, 'city', 'VARCHAR', 0, None, 0),
#  (7, 'state', 'VARCHAR', 0, None, 0),
#  (8, 'zip', 'VARCHAR', 0, None, 0),
#  (9, 'amount', 'INTEGER', 0, None, 0),
#  (10, 'date', 'DATETIME', 0, None, 0),
#  (11, 'candidate_id', 'INTEGER', 1, None, 0),
#  (12, 'name', '', 0, None, 0)]

# %%
out = make_query("SELECT id, last_name,first_name from contributors;")
out2 = [(e[1]+", "+e[2],e[0]) for e in out]
out2[:5]
# Out:
# [('Agee, Steven', 1),
#  ('Ahrens, Don', 2),
#  ('Ahrens, Don', 3),
#  ('Ahrens, Don', 4),
#  ('Akin, Charles', 5)]

# %%
alt2="UPDATE contributors SET name = ? WHERE id = ?;"
for ele in out2:
    db.cursor().execute(alt2, ele)
db.commit()

# %%
out=make_query("SELECT * from contributors;")
print(out[0])
make_frame(out,legend=contributor_cols+["name"]).head(10)
# Out:
# (1, 'Agee', 'Steven', None, '549 Laurel Branch Road', None, 'Floyd', 'VA', '24091', 500, '2007-06-30', 16, 'Agee, Steven')
#    id last_name first_name middle_name                      street_1 street_2  \
# 0   1      Agee     Steven        None        549 Laurel Branch Road     None
# 1   2    Ahrens        Don        None          4034 Rennellwood Way     None
# 2   3    Ahrens        Don        None          4034 Rennellwood Way     None
# 3   4    Ahrens        Don        None          4034 Rennellwood Way     None
# 4   5      Akin    Charles        None        10187 Sugar Creek Road     None
# 5   6      Akin       Mike        None              181 Baywood Lane     None
# 6   7      Akin    Rebecca        None              181 Baywood Lane     None
# 7   8  Aldridge    Brittni        None  808 Capitol Square Place, SW     None
# 8   9     Allen    John D.        None        1052 Cannon Mill Drive     None
# 9  10     Allen    John D.        None        1052 Cannon Mill Drive     None
#
#             city state    zip  amount        date  candidate_id  \
# 0          Floyd    VA  24091   500.0  2007-06-30            16
# 1     Pleasanton    CA  94566   250.0  2007-05-16            16
# 2     Pleasanton    CA  94566    50.0  2007-06-18            16
# 3     Pleasanton    CA  94566   100.0  2007-06-21            16
# 4    Bentonville    AR  72712   100.0  2007-06-16            16
# 5     Monticello    AR  71655  1500.0  2007-05-18            16
# 6     Monticello    AR  71655   500.0  2007-05-18            16
# 7     Washington    DC  20024   250.0  2007-06-06            16
# 8  North Augusta    SC  29860  1000.0  2007-06-11            16
# 9  North Augusta    SC  29860  1300.0  2007-06-29            16
#
#                 name
# 0       Agee, Steven
# 1        Ahrens, Don
# 2        Ahrens, Don
# 3        Ahrens, Don
# 4      Akin, Charles
# 5         Akin, Mike
# 6      Akin, Rebecca
# 7  Aldridge, Brittni
# 8     Allen, John D.
# 9     Allen, John D.

# %% [markdown]
# And lets now do an assignment to an existing column

# %%
upd="UPDATE contributors SET name = 'junk' WHERE state = 'VA';"
db.cursor().execute(upd)
db.commit()

# %%
out=make_query("SELECT * from contributors where state='VA';")
make_frame(out,contributor_cols+["name"]).head(10)
# Out:
#     id  last_name first_name middle_name                     street_1  \
# 0    1       Agee     Steven        None       549 Laurel Branch Road
# 1   28   Buckheit      Bruce        None                8904 KAREN DR
# 2   78  Ranganath      Anoop        None           2507 Willard Drive
# 3   89  Perreault     Louise        None    503 Brockridge Hunt Drive
# 4  146    ABDELLA     THOMAS          M.  4231 MONUMENT WALL WAY #340
#
#   street_2             city state        zip  amount        date  \
# 0     None            Floyd    VA      24091  500.00  2007-06-30
# 1     None          FAIRFAX    VA  220312731  100.00  2007-09-19
# 2     None  Charlottesville    VA      22903 -100.00  2008-04-21
# 3     None          Hampton    VA      23666  -34.08  2008-04-21
# 4     None          FAIRFAX    VA  220308440   50.00  2007-09-30
#
#    candidate_id  name
# 0            16  junk
# 1            20  junk
# 2            32  junk
# 3            32  junk
# 4            35  junk

# %% [markdown]
# ## DELETE
#
# Deletion can be based on a criterion, or one might delete an entire column, re even a table (DROP Table)

# %%
out=make_query("DELETE from contributors WHERE name='junk';")
make_frame(out, contributor_cols+['name']).head(10)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 out=make_query("DELETE from contributors WHERE name='junk';")
#       2 make_frame(out, contributor_cols+['name']).head(10)
#
# Cell In[15], line 2, in make_query(sel)
#       1 def make_query(sel):
# ----> 2     c=db.cursor().execute(sel)
#       3     return c.fetchall()
#
# OperationalError: no such column: name

# %%
out=make_query("select * from contributors WHERE state='MA';")
make_frame(out, contributor_cols+['name']).head(10)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[79], line 2
#       1 out=make_query("select * from contributors WHERE state='MA';")
# ----> 2 make_frame(out, contributor_cols+['name']).head(10)
#
# Cell In[4], line 5, in make_frame(list_of_tuples, legend)
#       3 framelist=[]
#       4 for i, cname in enumerate(legend):
# ----> 5     framelist.append((cname,[e[i] for e in list_of_tuples]))
#       6 return pd.DataFrame.from_dict(OrderedDict(framelist))
#
# IndexError: tuple index out of range

# %% [markdown]
# ### No DROP COLUMN in SQLITE
#
# Its available in other databases. Here you must just re-create your database, or know about this gotcha from the start. (reasons here: https://www.quora.com/Why-cant-SQLite-drop-columns)

# %%
alt="ALTER TABLE contributors DROP COLUMN name;"
db.cursor().execute(alt)
db.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[80], line 2
#       1 alt="ALTER TABLE contributors DROP COLUMN name;"
# ----> 2 db.cursor().execute(alt)
#       3 db.commit()
#
# OperationalError: no such column: "name"

# %% [markdown]
# Its much simpler in Pandas, of-course

# %%
out=make_query("select * from contributors")
make_frame(out, contributor_cols).head(10)
# Out:
#    id last_name first_name middle_name                      street_1 street_2  \
# 0   2    Ahrens        Don        None          4034 Rennellwood Way     None
# 1   3    Ahrens        Don        None          4034 Rennellwood Way     None
# 2   4    Ahrens        Don        None          4034 Rennellwood Way     None
# 3   5      Akin    Charles        None        10187 Sugar Creek Road     None
# 4   6      Akin       Mike        None              181 Baywood Lane     None
# 5   7      Akin    Rebecca        None              181 Baywood Lane     None
# 6   8  Aldridge    Brittni        None  808 Capitol Square Place, SW     None
# 7   9     Allen    John D.        None        1052 Cannon Mill Drive     None
# 8  10     Allen    John D.        None        1052 Cannon Mill Drive     None
# 9  11   Allison    John W.        None                 P.O. Box 1089     None
#
#             city state    zip  amount        date  candidate_id
# 0     Pleasanton    CA  94566   250.0  2007-05-16            16
# 1     Pleasanton    CA  94566    50.0  2007-06-18            16
# 2     Pleasanton    CA  94566   100.0  2007-06-21            16
# 3    Bentonville    AR  72712   100.0  2007-06-16            16
# 4     Monticello    AR  71655  1500.0  2007-05-18            16
# 5     Monticello    AR  71655   500.0  2007-05-18            16
# 6     Washington    DC  20024   250.0  2007-06-06            16
# 7  North Augusta    SC  29860  1000.0  2007-06-11            16
# 8  North Augusta    SC  29860  1300.0  2007-06-29            16
# 9         Conway    AR  72033  1000.0  2007-05-18            16

# %%
dfcwci
# Out:
#       last_name first_name middle_name                      street_1 street_2  \
# 0          Agee     Steven         NaN        549 Laurel Branch Road      NaN
# 4          Akin    Charles         NaN        10187 Sugar Creek Road      NaN
# 5          Akin       Mike         NaN              181 Baywood Lane      NaN
# 6          Akin    Rebecca         NaN              181 Baywood Lane      NaN
# 7      Aldridge    Brittni         NaN  808 Capitol Square Place, SW      NaN
# ..          ...        ...         ...                           ...      ...
# 170    ABESHAUS    MERRILL          M.        1801 N. HEREFORD DRIVE      NaN
# 171     ABRAHAM     GEORGE         NaN                 P.O. BOX 1504      NaN
# 172  ABRAHAMSON      PETER          J.         1030 W. ROSCOE STREET      NaN
# 173     ABRAHAM      SALEM          A.                    P.O. BOX 7      NaN
# 174     ABRAHAM      SALEM          A.                    P.O. BOX 7      NaN
#
#              city state        zip  amount        date  candidate_id
# 0           Floyd    VA      24091   500.0  2007-06-30            16
# 4     Bentonville    AR      72712   100.0  2007-06-16            16
# 5      Monticello    AR      71655  1500.0  2007-05-18            16
# 6      Monticello    AR      71655   500.0  2007-05-18            16
# 7      Washington    DC      20024   250.0  2007-06-06            16
# ..            ...   ...        ...     ...         ...           ...
# 170     FLAGSTAFF    AZ  860011121   120.0  2008-01-16            37
# 171  LAKE CHARLES    LA  706021504   800.0  2008-01-17            37
# 172       CHICAGO    IL  606572207    50.0  2008-01-25            37
# 173      CANADIAN    TX  790140007  1000.0  2008-01-17            37
# 174      CANADIAN    TX  790140007  1300.0  2008-01-30            37
#
# [172 rows x 11 columns]

# %%
del dfcwci['name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/sci1/SQLandPandas/.pixi/envs/default/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 del dfcwci['name']
#
# File ~/sci1/SQLandPandas/.pixi/envs/default/lib/python3.12/site-packages/pandas/core/generic.py:4503, in NDFrame.__delitem__(self, key)
#    4498             deleted = True
#    4499 if not deleted:
#    4500     # If the above loop ran and didn't delete anything because
#    4501     # there was no match, this call should raise the appropriate
#    4502     # exception:
# -> 4503     loc = self.axes[-1].get_loc(key)
#    4504     self._mgr = self._mgr.idelete(loc)
#    4506 # delete from the caches
#
# File ~/sci1/SQLandPandas/.pixi/envs/default/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'name'

# %% [markdown]
# But you might want to DELETE, just as in a SELECT, based on a criterion...

# %%
dfcwci=dfcwci[dfcwci.last_name!='Ahrens']
dfcwci.head(10)
# Out:
#    last_name first_name middle_name                      street_1 street_2  \
# 0       Agee     Steven         NaN        549 Laurel Branch Road      NaN
# 4       Akin    Charles         NaN        10187 Sugar Creek Road      NaN
# 5       Akin       Mike         NaN              181 Baywood Lane      NaN
# 6       Akin    Rebecca         NaN              181 Baywood Lane      NaN
# 7   Aldridge    Brittni         NaN  808 Capitol Square Place, SW      NaN
# 8      Allen    John D.         NaN        1052 Cannon Mill Drive      NaN
# 9      Allen    John D.         NaN        1052 Cannon Mill Drive      NaN
# 10   Allison    John W.         NaN                 P.O. Box 1089      NaN
# 11   Allison    Rebecca         NaN             3206 Summit Court      NaN
# 12   Allison    Rebecca         NaN             3206 Summit Court      NaN
#
#              city state    zip  amount        date  candidate_id
# 0           Floyd    VA  24091   500.0  2007-06-30            16
# 4     Bentonville    AR  72712   100.0  2007-06-16            16
# 5      Monticello    AR  71655  1500.0  2007-05-18            16
# 6      Monticello    AR  71655   500.0  2007-05-18            16
# 7      Washington    DC  20024   250.0  2007-06-06            16
# 8   North Augusta    SC  29860  1000.0  2007-06-11            16
# 9   North Augusta    SC  29860  1300.0  2007-06-29            16
# 10         Conway    AR  72033  1000.0  2007-05-18            16
# 11    Little Rock    AR  72227  1000.0  2007-04-25            16
# 12    Little Rock    AR  72227   200.0  2007-06-12            16

# %%
drow="DELETE FROM contributors WHERE last_name=\"Ahrens\";"
db.cursor().execute(drow)
db.commit()
out=make_query("SELECT * FROM contributors;")
make_frame(out, legend=contributor_cols).head(10)
# Out:
#    id last_name first_name middle_name                      street_1 street_2  \
# 0   5      Akin    Charles        None        10187 Sugar Creek Road     None
# 1   6      Akin       Mike        None              181 Baywood Lane     None
# 2   7      Akin    Rebecca        None              181 Baywood Lane     None
# 3   8  Aldridge    Brittni        None  808 Capitol Square Place, SW     None
# 4   9     Allen    John D.        None        1052 Cannon Mill Drive     None
# 5  10     Allen    John D.        None        1052 Cannon Mill Drive     None
# 6  11   Allison    John W.        None                 P.O. Box 1089     None
# 7  12   Allison    Rebecca        None             3206 Summit Court     None
# 8  13   Allison    Rebecca        None             3206 Summit Court     None
# 9  14     Altes       R.D.        None               8600 Moody Road     None
#
#             city state    zip  amount        date  candidate_id
# 0    Bentonville    AR  72712   100.0  2007-06-16            16
# 1     Monticello    AR  71655  1500.0  2007-05-18            16
# 2     Monticello    AR  71655   500.0  2007-05-18            16
# 3     Washington    DC  20024   250.0  2007-06-06            16
# 4  North Augusta    SC  29860  1000.0  2007-06-11            16
# 5  North Augusta    SC  29860  1300.0  2007-06-29            16
# 6         Conway    AR  72033  1000.0  2007-05-18            16
# 7    Little Rock    AR  72227  1000.0  2007-04-25            16
# 8    Little Rock    AR  72227   200.0  2007-06-12            16
# 9     Fort Smith    AR  72903  2300.0  2007-06-21            16

# %%
db.close()
